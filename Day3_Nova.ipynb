# %% [markdown]
# <a href="https://colab.research.google.com/github/rebmcph1-afk/nova-ds-ai-bootcamp-2026/blob/main/Day3_Nova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 3 — Data Cleaning & Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Learning Objectives
# - Handle missing data
# - Identify outliers
# - Convert data types
# - Create visualizations
# - Explain code using AI assistance

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np

# Load dataset
housing = fetch_california_housing(as_frame=True)
df = housing.frame

df.head()

# %% [markdown]
# # Basic Data Cleaning
#
# Using pandas to check for missing values #isna

# %%
df.isna().sum()

# %% [markdown]
# # Summary statistics

# %%
df.describe()

# %% [markdown]
# # Rename columns for readability

# %%
df = df.rename(columns={
    "MedInc": "median_income",
    "HouseAge": "house_age",
    "AveRooms": "avg_rooms",
    "AveBedrms": "avg_bedrooms",
    "Population": "population",
    "AveOccup": "avg_occupancy",
    "Latitude": "latitude",
    "Longitude": "longitude",
    "MedHouseVal": "median_house_value"
})

df.head()

# %% [markdown]
# # Remove impossible or extreme values

# %%
# Example: avg_rooms should not be zero
df = df[df["avg_rooms"] > 0]

# Remove negative income values (shouldn't exist)
df = df[df["median_income"] > 0]

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)

# %% [markdown]
# # Distribution plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["median_house_value"], kde=True)
plt.title("Distribution of Median House Value")
plt.show()

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Scatter: Income vs House Value

# %%
sns.scatterplot(
    data=df,
    x="median_income",
    y="median_house_value",
    alpha=0.3
)
plt.title("Income vs House Value")
plt.show()

# %% [markdown]
# # Scatter: Latitude/Longitude (quick geospatial look)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="longitude",
    y="latitude",
    hue="median_house_value",
    palette="viridis",
    alpha=0.5
)
plt.title("California Housing Prices by Location")
plt.show()

# %% [markdown]
# ## Hands-On Exercise
# Clean the dataset and create 3 visualizations.
# Use AI to generate code, but explain each line.

# %% [markdown]
# ## Assignment
# Submit:
# - Cleaned dataset
# - 1-page EDA summary
